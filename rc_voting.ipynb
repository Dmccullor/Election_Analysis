# %%
import os
import pandas as pd
import random as rd
import csv

election_data_to_read = "Resources/election_results.csv"
election_data_df = pd.read_csv(election_data_to_read)

election_data_df.head()
# Out:
#    Ballot ID     County                Candidate
# 0    1323913  Jefferson  Charles Casper Stockham
# 1    1005842  Jefferson  Charles Casper Stockham
# 2    1880345  Jefferson  Charles Casper Stockham
# 3    1600337  Jefferson  Charles Casper Stockham
# 4    1835994  Jefferson  Charles Casper Stockham

# %%
candidate_list = election_data_df.sort_values(["Candidate"])
candidate_list
# Out:
#         Ballot ID     County                Candidate
# 0         1323913  Jefferson  Charles Casper Stockham
# 67245     2871495     Denver  Charles Casper Stockham
# 67244     2002887     Denver  Charles Casper Stockham
# 67243     2650977     Denver  Charles Casper Stockham
# 67242     2426080     Denver  Charles Casper Stockham
# ...           ...        ...                      ...
# 339357    3253513     Denver     Raymon Anthony Doane
# 339358    3572325     Denver     Raymon Anthony Doane
# 339359    3115551     Denver     Raymon Anthony Doane
# 339350    3704663     Denver     Raymon Anthony Doane
# 369710    4660518   Arapahoe     Raymon Anthony Doane
#
# [369711 rows x 3 columns]

# %%
candidate_count = election_data_df.groupby(["Candidate"]).count()["Ballot ID"]
candidate_count
# Out:
# Candidate
# Charles Casper Stockham     85213
# Diana DeGette              272892
# Raymon Anthony Doane        11606
# Name: Ballot ID, dtype: int64

# %%
county_count = election_data_df.groupby(["County"]).count()["Ballot ID"]
county_count
# Out:
# County
# Arapahoe      24801
# Denver       306055
# Jefferson     38855
# Name: Ballot ID, dtype: int64

# %%
election_data_df["Ballot ID"].count()
# Out:
# 369711

# %%
election_data_df.dtypes
# Out:
# Ballot ID     int64
# County       object
# Candidate    object
# dtype: object

# %%
from RC_voting import second_choice_list
from RC_voting import third_choice_list

third_choice_list
# Out:
# ['Diana DeGette',
#  'Raymon Anthony Doane',
#  'Diana DeGette',
#  'Diana DeGette',
#  'Raymon Anthony Doane',
#  'Raymon Anthony Doane',
#  'Diana DeGette',
#  'Raymon Anthony Doane',
#  'Raymon Anthony Doane',
#  'Raymon Anthony Doane',
#  'Raymon Anthony Doane',
#  'Diana DeGette',
#  'Raymon Anthony Doane',
#  'Diana DeGette',
#  'Diana DeGette',
#  'Raymon Anthony Doane',
#  'Diana DeGette',
#  'Diana DeGette',
#  'Diana DeGette',
#  'Raymon Anthony Doane',
#  'Diana DeGette',
#  'Raymon Anthony Doane',
#  'Diana DeGette',
#  'Raymon Anthony Doane',
#  'Diana DeGette',
#  'Raymon Anthony Doane',
#  'Raymon Anthony Doane',
#  'Diana DeGette',
#  'Diana DeGette',
#  'Diana DeGette',
#  'Diana DeGette',
#  'Diana DeGette',
#  'Diana DeGette',
#  'Diana DeGette',
#  'Diana DeGette',
#  'Raymon Anthony Doane',
#  'Diana DeGette',
#  'Diana DeGette',
#  'Diana DeGette',
#  'Diana DeGette',
#  'Raymon Anthony Doane',
#  'Raymon Anthony Doane',
#  'Raymon Anthony Doane',
# ...

# %%
second_choice = pd.Series(second_choice_list)
third_choice = pd.Series(third_choice_list)

# %%
election_data_df["Second Choice"] = second_choice
election_data_df["Third Choice"] = third_choice
election_data_df.head(10)
# Out:
#    Ballot ID     County                Candidate         Second Choice  \
# 0    1323913  Jefferson  Charles Casper Stockham  Raymon Anthony Doane
# 1    1005842  Jefferson  Charles Casper Stockham         Diana DeGette
# 2    1880345  Jefferson  Charles Casper Stockham  Raymon Anthony Doane
# 3    1600337  Jefferson  Charles Casper Stockham  Raymon Anthony Doane
# 4    1835994  Jefferson  Charles Casper Stockham         Diana DeGette
# 5    1772756  Jefferson  Charles Casper Stockham         Diana DeGette
# 6    1920023  Jefferson  Charles Casper Stockham  Raymon Anthony Doane
# 7    1040408  Jefferson  Charles Casper Stockham         Diana DeGette
# 8    1018414  Jefferson  Charles Casper Stockham         Diana DeGette
# 9    1361118  Jefferson  Charles Casper Stockham         Diana DeGette
#
#            Third Choice
# 0         Diana DeGette
# 1  Raymon Anthony Doane
# 2         Diana DeGette
# 3         Diana DeGette
# 4  Raymon Anthony Doane
# 5  Raymon Anthony Doane
# ...

# %%
election_data_df.to_csv("Resources/rc_election_results.csv", index=False)
